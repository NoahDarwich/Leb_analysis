# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/Lebanon_89-2010 - Sheet1.csv', header=1, index_col='recordnumber')
df.head(5)
# Out:
# /home/noahdarwich/.pyenv/versions/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3106: DtypeWarning: Columns (127,133,139,188,189,190,192) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              coderinitials   datecoded  \
# recordnumber
# 89901001.0              ND  2019-02-22
# 89901002.0              ND  2019-02-22
# 89901003.0              ND  2019-02-22
# 89901004.0              ND  2019-02-22
# 89901005.0              ND  2019-02-22
#
#                                                       narrative nameofevent  \
# recordnumber
# 89901001.0    اعتصام في برج البراجنة امام مستشفى حيفا , دعت ...         NaN
# 89901002.0    نظم الاتحاد العام للمرأة الفلسطينية اعتصام في ...         NaN
# 89901003.0    نظمت جبهة الانقاذ الوطني الفلسطينية اعتصام في ...         NaN
# 89901004.0    نظمت جبهة الانقاذ الوطني الفلسطينية اعتصام في ...         NaN
# ...

# %%
demand_df = pd.read_csv('../Data/lebanon demand - Sheet1.csv')
# Out:
# Float64Index([89901001.0, 89901002.0, 89901003.0, 89901004.0, 89901005.0,
#               89901006.0, 89901007.0, 89901008.0, 89901009.0, 89901010.0,
#               ...
#               20191953.0, 20191954.0, 20191955.0, 20191956.0, 20191957.0,
#               20191958.0, 20191959.0, 20191960.0, 20191961.0, 20191962.0],
#              dtype='float64', name='recordnumber', length=8178)
